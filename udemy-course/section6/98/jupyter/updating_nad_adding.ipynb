# %%
import pandas

# %%
df = pandas.read_csv('../data.txt', header = None, names = ['ID', 'Address', 'City', 'Index', 'Country', 'Name', 'Points'])
df
# Out:
#    ID          Address           City             Index Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Points
# 0       8
# 1      15
# 2      25
# 3      10
# 4      12
# 5      20

# %%
# df.shape - returns tuple with nuber of rows and colums (ROWS, COLUMNS)
df['Continent'] = ['North America']*df.shape[0]
df
# Out:
#    ID          Address           City             Index Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Points      Continent
# 0       8  North America
# 1      15  North America
# 2      25  North America
# 3      10  North America
# 4      12  North America
# 5      20  North America

# %%
df['Continent'] = df['Country']+', '+'North America'
df
# Out:
#    ID          Address           City             Index Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Points           Continent
# 0       8  USA, North America
# 1      15  USA, North America
# 2      25  USA, North America
# 3      10  USA, North America
# 4      12  USA, North America
# 5      20  USA, North America

# %%
df_t = df.T
df_t
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# Index                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Points                      8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df_t[6] = [7, '231 Battle st', 'San Francisco', 'CA2131', 'USA', 'Bubble', 12, 'USA, North America']
df_t
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# Index                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Points                      8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5  \
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df = df_t.T
df
# Out:
#   ID          Address           City             Index Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# 6  7    231 Battle st  San Francisco            CA2131     USA       Bubble
#
#   Points           Continent
# 0      8  USA, North America
# 1     15  USA, North America
# 2     25  USA, North America
# 3     10  USA, North America
# 4     12  USA, North America
# 5     20  USA, North America
# 6     12  USA, North America

# %%
df.loc[0, 'Name'] = 'Flambe'
df
# Out:
#   ID          Address           City             Index Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA       Flambe
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# 6  7    231 Battle st  San Francisco            CA2131     USA       Bubble
#
#   Points           Continent
# 0      8  USA, North America
# 1     15  USA, North America
# 2     25  USA, North America
# 3     10  USA, North America
# 4     12  USA, North America
# 5     20  USA, North America
# 6     12  USA, North America

# %%
df.loc[0:1, 'City':'Name'] = [['New York', 'NY213', 'USA', 'Green'],['London', 'L231', 'England', 'Boris']]
df
# Out:
#   ID          Address           City             Index  Country         Name  \
# 0  1     3666 21st St       New York             NY213      USA        Green
# 1  2   735 Dolores St         London              L231  England        Boris
# 2  3      332 Hill St  San Francisco  California 94114      USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
# 6  7    231 Battle st  San Francisco            CA2131      USA       Bubble
#
#   Points           Continent
# 0      8  USA, North America
# 1     15  USA, North America
# 2     25  USA, North America
# 3     10  USA, North America
# 4     12  USA, North America
# 5     20  USA, North America
# 6     12  USA, North America
